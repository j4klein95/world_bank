# %%
import pandas as pd
import numpy as np

from bokeh.io import curdoc, output_notebook, output_file, push_notebook, show
from bokeh.layouts import row, widgetbox, column
from bokeh.models import ColumnDataSource, HoverTool
from bokeh.models.widgets import Slider, TextInput, Select
from bokeh.plotting import figure

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="c00ff4af-888d-4769-bec5-47c6d7a6cfba">Loading BokehJS ...</span>
#     </div>

# %%
gdp_df = pd.read_csv('../cleaned_resources/clean_gdp_US.csv')
edu_df = pd.read_csv('../cleaned_resources/clean_sec_edu.csv')

# %%
gdp_df.head(3)
# Out:
#   Country Name        Series Name  2003 [YR2003]  2004 [YR2004]  \
# 0  Afghanistan  GDP (current US$)   4.583644e+09   5.285466e+09
# 1      Albania  GDP (current US$)   5.746946e+09   7.314865e+09
# 2      Algeria  GDP (current US$)   6.786383e+10   8.532500e+10
#
#    2005 [YR2005]  2006 [YR2006]  2007 [YR2007]  2008 [YR2008]  2009 [YR2009]  \
# 0   6.275074e+09   7.057598e+09   9.843842e+09   1.019053e+10   1.248694e+10
# 1   8.158549e+09   8.992642e+09   1.070101e+10   1.288135e+10   1.204421e+10
# 2   1.031982e+11   1.170273e+11   1.349771e+11   1.710007e+11   1.372110e+11
#
#    2010 [YR2010]  2011 [YR2011]  2012 [YR2012]  2013 [YR2013]  2014 [YR2014]  \
# 0   1.593680e+10   1.793024e+10   2.053654e+10   2.004633e+10   2.005019e+10
# 1   1.192695e+10   1.289087e+10   1.231978e+10   1.277628e+10   1.322824e+10
# 2   1.612073e+11   2.000191e+11   2.090590e+11   2.097550e+11   2.138100e+11
#
#    2015 [YR2015]  2016 [YR2016]  2017 [YR2017]
# ...

# %%
edu_df.head(3)
# Out:
#                                          Series Name  2003 [YR2003]  \
# Country Name
# Afghanistan   School enrollment, secondary (% gross)      13.317080
# Albania       School enrollment, secondary (% gross)      75.018990
# Algeria       School enrollment, secondary (% gross)      73.755661
#
#               2004 [YR2004]  2005 [YR2005]  2006 [YR2006]  2007 [YR2007]  \
# Country Name
# Afghanistan       18.664789      19.783701      29.930460      30.083160
# Albania           74.170280      76.887062      77.955887      81.280869
# Algeria           77.213402      78.782227      79.791580      70.281212
#
#               2008 [YR2008]  2009 [YR2009]  2010 [YR2010]  2011 [YR2011]  \
# Country Name
# Afghanistan       40.223381      46.732761      53.246830      54.616180
# Albania           83.648918      85.409309      88.411636      90.848351
# Algeria           76.755852      93.070030      97.171921      99.860191
#
# ...

# %%
edu_df = edu_df.set_index('Country Name')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/jayklein95/anaconda/envs/PythonData/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2392             try:
# -> 2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5239)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5085)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20405)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20359)()
#
# KeyError: 'Country Name'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
gdp_df = gdp_df.set_index('Country Name')
gdp_df
# Out:
#                                 Series Name  2003 [YR2003]  2004 [YR2004]  \
# Country Name
# Afghanistan               GDP (current US$)   4.583644e+09   5.285466e+09
# Albania                   GDP (current US$)   5.746946e+09   7.314865e+09
# Algeria                   GDP (current US$)   6.786383e+10   8.532500e+10
# American Samoa            GDP (current US$)   5.270000e+08   5.120000e+08
# Andorra                   GDP (current US$)   2.398646e+09   2.935659e+09
# Angola                    GDP (current US$)   1.418895e+10   1.964085e+10
# Antigua and Barbuda       GDP (current US$)   8.556431e+08   9.195771e+08
# Arab World                GDP (current US$)   8.231105e+11   9.638623e+11
# Argentina                 GDP (current US$)   1.275870e+11   1.646579e+11
# Armenia                   GDP (current US$)   2.807061e+09   3.576615e+09
# Aruba                     GDP (current US$)   2.021302e+09   2.228279e+09
# ...

# %%
edu_df.keys()
# Out:
# Index(['Series Name', '2003 [YR2003]', '2004 [YR2004]', '2005 [YR2005]',
#        '2006 [YR2006]', '2007 [YR2007]', '2008 [YR2008]', '2009 [YR2009]',
#        '2010 [YR2010]', '2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]',
#        '2014 [YR2014]', '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]'],
#       dtype='object')

# %%
gdp_df.keys()
# Out:
# Index(['Series Name', '2003 [YR2003]', '2004 [YR2004]', '2005 [YR2005]',
#        '2006 [YR2006]', '2007 [YR2007]', '2008 [YR2008]', '2009 [YR2009]',
#        '2010 [YR2010]', '2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]',
#        '2014 [YR2014]', '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]'],
#       dtype='object')

# %%
bigWb_df = pd.read_csv('../cleaned_resources/clean_wb_1.csv')
